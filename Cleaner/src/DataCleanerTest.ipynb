# %%
from DataCleaner import DataCleaner

# %%
DR = DataCleaner('B000027-2016-04-13-12-19-meysam-1xB1TB1-40C-260uL-2MHz-P0-B103mM-PhiX2200-1B2S-FF20-I07_EMsruUBJFQ')

# %%
DR.id
# Out:
# 'B000027-2016-04-13-12-19-meysam-1xB1TB1-40C-260uL-2MHz-P0-B103mM-PhiX2200-1B2S-FF20-I07_EMsruUBJFQ'

# %%
DR.getConfig(DR._config_file)

# %%
DR.getChipCheck()

# %%
DR.getBasicInfo()

# %%
DR.setPaths()

# %%
DR.calcReadConfig()

# %%
DR.dumpRunInfo()

# %%
DR.getChipInfo()

# %%
DR.createMask()

# %%
DR.instrumentData()

# %%
DR.instrument_data
# Out:
#           TimeStamp  FlowSensor  FlowSensor2  FlowSensor3  \
# 0      1.460575e+12   -0.310345    -0.344828    -0.103448
# 1      1.460575e+12   -0.379310    -0.310345    -0.103448
# 2      1.460575e+12   -0.379310    -0.310345    -0.103448
# 3      1.460575e+12   -0.379310    -0.310345    -0.103448
# 4      1.460575e+12   -0.379310    -0.310345    -0.103448
# 5      1.460575e+12   -0.379310    -0.310345    -0.103448
# 6      1.460575e+12   -0.344828    -0.310345    -0.034483
# 7      1.460575e+12   -0.344828    -0.310345    -0.034483
# 8      1.460575e+12   -0.068966    -0.310345    -0.034483
# 9      1.460575e+12   -0.068966    -0.310345    -0.034483
# 10     1.460575e+12   -0.068966    -0.310345    -0.034483
# 11     1.460575e+12   -0.034483    -0.344828    -0.034483
# 12     1.460575e+12   -0.034483    -0.344828    -0.034483
# 13     1.460575e+12    0.000000    -0.344828    -0.034483
# 14     1.460575e+12    0.000000    -0.344828    -0.034483
# ...

# %%
DR.sensorReads()

# %%
DR.sensor_reads
# Out:
#                noMagentAverage  withMagnetAverage InstrumentState  \
# 1460084474765          1604.67             219.36            read
# 1460084475586          1815.14             294.60            read
# 1460084476407          2021.01             341.47            read
# 1460084477228          2214.42             390.42            read
# 1460084478050          2421.81             399.54            read
# 1460084476545          2624.51             456.01            read
# 1460084477366          2780.74             467.75            read
# 1460084478187          2867.92             505.51            read
# 1460084479008          3005.60             504.93            read
# 1460084479830          3119.87             555.52            read
# 1460084478338          3264.30             546.94            read
# 1460084479159          3328.59             609.87            read
# 1460084479980          3385.82             580.61            read
# ...
