# %%
from DataCleaner import DataCleaner

# %%
DR = DataCleaner('B000028-2016-01-31-14-20-s.perumal-12xB1-1xLongT-1xCG-12xTCAGB1-23XTCAG-Prll-PMK2909-PhiX-2500-2560-Pil-blkd-FF18-P05_hbJDkADBhS')

# %%
DR.id
# Out:
# 'B000028-2016-01-31-14-20-s.perumal-12xB1-1xLongT-1xCG-12xTCAGB1-23XTCAG-Prll-PMK2909-PhiX-2500-2560-Pil-blkd-FF18-P05_hbJDkADBhS'

# %%
DR.getConfig(DR._config_file)

# %%
DR.getChipCheck()

# %%
DR.getBasicInfo()

# %%
DR.setPaths()

# %%
DR.calcReadConfig()

# %%
DR.dumpRunInfo()

# %%
DR.getChipInfo()

# %%
DR.createMask()

# %%
DR.instrumentData()

# %%
DR.instrument_data
# Out:
#            TimeStamp  FlowSensor  FlowSensor2  FlowSensor3  \
# 0       1.454279e+12   -0.068966    -0.275862    -0.482759
# 1       1.454279e+12   -0.137931    -0.206897    -0.482759
# 2       1.454279e+12   -0.137931    -0.206897    -0.482759
# 3       1.454279e+12   -0.137931    -0.206897    -0.482759
# 4       1.454279e+12   -0.034483    -0.206897    -0.482759
# 5       1.454279e+12   -0.034483    -0.206897    -0.482759
# 6       1.454279e+12    0.000000    -0.206897    -0.551724
# 7       1.454279e+12    0.000000    -0.206897    -0.551724
# 8       1.454279e+12    0.000000    -0.206897    -0.551724
# 9       1.454279e+12   -0.172414    -0.206897    -0.551724
# 10      1.454279e+12   -0.172414    -0.206897    -0.551724
# 11      1.454279e+12   -0.103448    -0.206897    -0.551724
# 12      1.454279e+12   -0.103448    -0.206897    -0.551724
# 13      1.454279e+12   -0.103448    -0.206897    -0.551724
# 14      1.454279e+12   -0.103448    -0.206897    -0.551724
# ...

# %%
DR.sensorReads()
# Out:
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600
# 3700
# 3800
# 3900
# 4000
# 4100
# 4200
# 4300
# 4400
# 4500
# 4600
# 4700

# %%
DR.sensor_reads
# Out:
#                noMagentAverage  withMagnetAverage InstrumentState  \
# 1454280706822          1914.83             -55.68         barrier
# 1454280707901          4126.58             685.46         barrier
# 1454280708981          5956.33            1318.16         barrier
# 1454280710061          7422.19            1678.19         barrier
# 1454280711141          8503.65            1922.64         barrier
# 1454280712264          9203.67            1972.48         barrier
# 1454280713343          9652.21            2233.04         barrier
# 1454280714423          9915.43            2345.14         barrier
# 1454280715503         10117.93            2481.44         barrier
# 1454280716583         10267.36            2609.58         barrier
# 1454280717722         10350.86            2618.26         barrier
# 1454280718801         10395.86            2730.08         barrier
# 1454280719881         10456.59            2893.71         barrier
# ...
